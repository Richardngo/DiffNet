# %%
import json

# %%
from constants import MIN_ITEM_REVIEWS, MIN_USER_FRIENDS, MIN_USER_REVIEWS, RAW_DIR
data_dir = (
        f"{RAW_DIR}/u_{MIN_USER_REVIEWS}_i_{MIN_ITEM_REVIEWS}_f_{MIN_USER_FRIENDS}"
    )
out_dir = f"{data_dir}/out"

# %%
with open("/Users/dharahastallapally/masters/code/data-tool/data/raw/u_20_i_20_f_20/sample/ZGjgfSvjQK886kiTzLwfLQ.json") as f:
    reviews = json.load(f)

# %%
import smart_open
import gensim

# %%
reviews = reviews['ZGjgfSvjQK886kiTzLwfLQ']

# %%
r = reviews[0]
r
# Out:
# "On a scale of one to things that are awesome, this place is the bomb. \n\nI was drawn in by the promise of the duckfat frenchfries. Took the boy for his birthday and put our name in, had a drink around the corner while we waited and were given seats at the bar after about 45 minutes. \n\nWe were waited on by Keith, the bartender, who was congenial, knowledgeable about his whiskeys and an all-around cool guy. We started with 3 cape may salts (two for me, one for the boy) and tater tots, both of which made me happy.\n\nFor dinner, I got Kentucky Fried Quail (stellar, though the succotash was not as exciting as I wanted it to be) and the boy got the 24$ Fois Gras burger, which was incredible. Worth every penny. The duckfat fries were pretty yummy, but not even the best part of the meal. I could've done without the cheese sauce, but as it was on the side I wasn't deterred.\n\nI look forward to coming back here, with everyone I know."

# %%
/Users/dharahastallapally/masters/code/data-tool/data/raw/u_20_i_20_f_20/reviews.json

# %%
import numpy as np

# %%
user = np.load(f"{out_dir}/yelp.item.embeddings.npy", allow_pickle=True)

# %%
user.shape
# Out:
# (6464, 300)

# %%
t = np.load(f'{data_dir}/item_embeddings.npy', allow_pickle=True)

# %%
t.item().keys()
# Out:
# dict_keys(['ZGjgfSvjQK886kiTzLwfLQ', 'IKbjLnfBQtEyVzEu8CuOLg', 'DBYhpb5hrAYgQjQaMhNYyQ', 'xbybLiQockAzC4xAlzFrGg', '07aVWNhBhpwqW3MdqoKDKQ', 'Zs8Zk3sgh5JxRmoZW4PJcg', 'Zp1o52IRl92dunmsfiT96g', 'x-LrGPXN7WFX15Qk9B6_YQ', 'u1cvQWB0lB4YsIbtSlUR7g', 'amIUTkKQlA4464-lJlwlaQ', 'dWTrJdEPoZB8LkOPv_jxsA', 'ci7Q6NvXQ8UZrBHusVX18g', 'nnImk681KaRqUVHlSfZjGQ', 'KhHwhL89YnbEw8RNM03C4A', 'dXgGp-vjO_TSIvLgNz5uaw', 'mzXDuhZBPdHfMIk1YXP0mQ', 'ovUBZdJI16y-qasoqnGt5Q', '2dyfZNhtyuHdestczTgWjQ', '5h9JA231vPilNAIjHxwGng', '_kp3hr0ohALINduHTERs9Q', 'fr1Hz2acAb3OaL3l6DyKNg', 'gL0PnnFMmJbWphaOh_6BsQ', 'TkFfkUhNLczx5LB-uR9qaw', 'dme9K6sQrgpojAay5r8IAA', 'vFd8aBLg1kFcd0kCkoi-xw', 'QASqmFDB1pIBF7xSp1PVeg', 'UYU71DRx-UDAee-eFOFfWw', 'kfiBpwAZFxAo_RcrBmQjbA', '5MLTOOiFGu_-PIyjhHIs-g', 'JW5W4OZCohTvZlRF1jzrTg', 'qjfMBIZpQT9DDtw_BWCopQ', '0MeivhX0kZCfV3zMtHtk9Q', 'K17847uudqPFPIjSPgxs2A', 'FI_UbbF0sZ1Bkxnp80vF_g', 'Y_2jMUKz6pvJ0JSWG3u10A', 'saQQmDQQJ14BVkm_sg53UA', 'HuoP7ejN-LSwkO1UIgmtaw', 'XuhpPK0bZgVenkGBh7KA6w',
# ...
